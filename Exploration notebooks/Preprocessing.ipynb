# %% [markdown]
# # Preprocessing
#
# En este NB se explora el impacto de las funciones de preprocesamiento que se implementen:

# %% [markdown]
# ## Importaciones

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import os
import numpy as np
import matplotlib.pylab as plt
from art.estimators.classification import PyTorchClassifier
# import cv2
from sklearn.metrics import confusion_matrix, accuracy_score
# import seaborn as sns

# %% [markdown]
# ## Procesamiento y carga de datos

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Data Preprocessing
transform_test = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ]
)

# Data Loading
testset = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=True, transform=transform_test
)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=128, shuffle=False, num_workers=2
)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## Funciones para normalizar y desnormalizar los datos

# %%
# Function to denormalize image
def denormalize(tensor, mean, std):
    denorm = torch.clone(tensor)
    for t, m, s in zip(denorm, mean, std):
        t.mul_(s).add_(m)
    return denorm


def normalize(tensor, mean, std):
    norm = torch.clone(tensor)
    for t, m, s in zip(norm, mean, std):
        t.sub_(m).div_(s)
    return norm


# Denormalize images
mean = torch.tensor([0.4914, 0.4822, 0.4465], dtype=torch.float32)
std = torch.tensor([0.2023, 0.1994, 0.2010], dtype=torch.float32)

# %% [markdown]
# ## Funciones para cargar los modelos

# %%
# Function to init the model
def init_model(lr=0.001, model_name="Resnet"):
    if model_name == "Resnet":
        model = models.resnet18(weights=torchvision.models.ResNet18_Weights.DEFAULT)
    elif model_name == "Regnet_X":
        model = models.regnet_x_400mf(
            weights=torchvision.models.RegNet_X_400MF_Weights.DEFAULT
        )
    elif model_name == "Regnet_Y":
        model = models.regnet_y_400mf(
            weights=torchvision.models.RegNet_Y_400MF_Weights.DEFAULT
        )

    # Fine-tuning: Replace the last layer (classifier)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 10)
    # Move model to GPU if available
    model = model.to(device)
    if device == "cuda":
        model = torch.nn.DataParallel(model)
        cudnn.benchmark = True
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=5e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
    return model, criterion, optimizer, scheduler

# Function to load the model
def load_model(model, name="ckpt.pth"):
    global best_acc
    print("==> Resuming from checkpoint..")
    assert os.path.isdir("checkpoint"), "Error: no checkpoint directory found!"
    if device == "cuda":
        checkpoint = torch.load("./checkpoint/" + name)
    else:
        checkpoint = torch.load(
            "./checkpoint/" + name, map_location=torch.device("cpu")
        )
    model.load_state_dict(checkpoint["model"])
    best_acc = checkpoint["acc"]
    start_epoch = checkpoint["epoch"]
    return start_epoch, best_acc

# %% [markdown]
# ## Función para cargar un modelo según el nombre

# %%
def classification(name_model):
    model, criterion, optimizer, scheduler = init_model(model_name=name_model[:-4])
    metrics = load_model(model, name=name_model)
    if device == "cuda":
        device_type = "gpu"
    else:
        device_type = "cpu"
    classifier = PyTorchClassifier(
        model=model,
        loss=criterion,
        optimizer=optimizer,
        nb_classes=10,
        input_shape=(3, 32, 32),
        device_type=device_type,
    )
    return classifier

# %% [markdown]
# ## Cargar los datos de los ejemplos adversariales

# %%
adversarial_resnet = torch.load("./Adversarial_examples/FastGradient_Method/all_data_denormed_Resnet.pt")
adversarial_regnet_x = torch.load("./Adversarial_examples/FastGradient_Method/all_data_denormed_Regnet_X.pt")
adversarial_regnet_y = torch.load("./Adversarial_examples/FastGradient_Method/all_data_denormed_Regnet_Y.pt")
adver_data = {
    "Resnet": adversarial_resnet,
    "Regnet_X": adversarial_regnet_x,
    "Regnet_Y": adversarial_regnet_y
}

# %% [markdown]
# ## Funciones para el preprocesamiento

# %%
def random_pixel(image, pixels = 20):
    h, w, ch = image.shape
    dist = image.copy()
    for _ in range(pixels):
        x1, y1 = np.random.randint(0, w), np.random.randint(0, h)
        x2, y2 = np.random.randint(0, w), np.random.randint(0, h)
        dist[x1, y1], dist[x2, y2] = (
            dist[x2, y2],
            dist[x1, y1],
        )
    return dist

def resize_pad(image, ratio = 0.8):
    original = image
    old_size = original.shape[:2]
    new_size = int(old_size[0]*ratio)
    img = cv2.resize(original, (new_size, new_size))
    max_y = old_size[0] - new_size
    max_x = old_size[1] - new_size
    start_y = np.random.randint(0, max_y)
    start_x = np.random.randint(0, max_x)
    pad = np.zeros_like(original)
    pad[start_y:start_y + new_size, start_x:start_x + new_size] = img
    return pad

def preprocess(image, classifier):
    # Get the image
    image = image.cpu().detach().numpy().transpose((1, 2, 0))
    
    # PREPROCESS 1: Resize and Padding
    defense = resize_pad(image)
    
    # PREPROCESS 2: Horizontal Flip
    defense = cv2.flip(defense, 1)
    
    # Defense Prediction
    defense = torch.tensor(defense.transpose((2, 0, 1)))
    norm = normalize(defense, mean, std)
    pred = np.argmax(classifier.predict(norm.unsqueeze(0)))
    defense = denormalize(norm, mean, std)
    return defense, pred

# %% [markdown]
# ## Visualizando el preprocesamiento

# %%
n = int(input('Write a number'))

for name_model, adver in adver_data.items():
    
    # Get the image
    image = adver["examples"][n]
    
    # Classifer
    classifier = classification(name_model = name_model+".pth")
    
    # Prepare the defense
    defense, pred = preprocess(image, classifier)
    
    # Plot the results and compare
    title = str(f"Model Resnet \n Real label: {testset.classes[adver['real_labels'][n]]} \n" +
        f"Model Prediction: {testset.classes[adver['model_labels'][n]]} \n" + 
        f"Adversarial Prediction: {testset.classes[adver['adversarial_labels'][n]]} \n" + 
        f"Defense Prediction: {testset.classes[pred]}")
    fig, ax = plt.subplots(1, 3, figsize=(8, 5.5))
    ax[0].imshow(denormalize(testset[n][0], mean, std).numpy().transpose((1, 2, 0)))
    ax[0].set_title("Real Image")
    ax[1].imshow(image.numpy().transpose((1, 2, 0)))
    ax[1].set_title("Adversarial Example")
    ax[2].imshow(defense.numpy().transpose((1, 2, 0)))
    ax[2].set_title("Defense")
    plt.suptitle(title)
    plt.show()
# Out:
# Write a number 78
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ==> Resuming from checkpoint..
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ==> Resuming from checkpoint..
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ## Creando los ejemplos con preprocesamiento

# %%
for name_model, adver in adver_data.items():
    images_defense = []
    pred_defense = []
    
    classifier = classification(name_model = name_model+".pth")
    
    for image in adver['examples']:
        defense, pred = preprocess(image, classifier)
        images_defense.append(defense)
        pred_defense.append(pred)
        
    all_defense_examples = torch.stack(images_defense)
    all_defense_labels = torch.tensor(pred_defense)
    
    os.makedirs("./Defense_examples/FastGradient_Method", exist_ok=True)
    
    defense_data = {
        "examples": adver['examples'],
        "real_labels": adver['real_labels'],
        "model_labels": adver['model_labels'],
        "adversarial_labels": adver['adversarial_labels'],
        "defense_examples": all_defense_examples,
        "defense_labels": all_defense_labels,
    }

    # Save the concatenated adversarial examples and labels
    torch.save(
        defense_data,
        f"./Defense_examples/FastGradient_Method/all_defense_denormed_{name_model}.pt",
    )
# Out:
# ==> Resuming from checkpoint..
# ==> Resuming from checkpoint..
# ==> Resuming from checkpoint..

# %% [markdown]
# ## Cargando las defensas

# %%
defense_resnet = torch.load("./Defense_examples/FastGradient_Method/all_defense_denormed_Resnet.pt")
defense_Regnet_X = torch.load("./Defense_examples/FastGradient_Method/all_defense_denormed_Regnet_X.pt")
defense_Regnet_Y = torch.load("./Defense_examples/FastGradient_Method/all_defense_denormed_Regnet_Y.pt")
defense_data = {
    "Resnet": defense_resnet,
    "Regnet_X": defense_Regnet_X,
    "Regnet_Y": defense_Regnet_Y,
}

# %% [markdown]
# ## Visualizando las defensas

# %%
for key, defense in defense_data.items():
    cm = confusion_matrix(defense['real_labels'].tolist(), defense['model_labels'].tolist())
    cm_adver = confusion_matrix(defense['real_labels'].tolist(), defense['adversarial_labels'].tolist())
    cm_defense = confusion_matrix(defense['real_labels'].tolist(), defense['defense_labels'].tolist())
    fig, ax = plt.subplots(1, 3, figsize = (17, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax[0])
    ax[0].set_xticks(np.arange(len(testset.classes))+0.5, testset.classes, rotation = 45)
    ax[0].set_yticks(np.arange(len(testset.classes))+0.5, testset.classes, rotation = 45)
    ax[0].set_title('CM with test data')
    sns.heatmap(cm_adver, annot=True, fmt="d", cmap="Blues", ax=ax[1])
    ax[1].set_xticks(np.arange(len(testset.classes))+0.5, testset.classes, rotation = 45)
    ax[1].set_yticks(np.arange(len(testset.classes))+0.5, testset.classes, rotation = 45)
    ax[1].set_title('CM with adversarial examples')
    sns.heatmap(cm_defense, annot=True, fmt="d", cmap="Blues", ax=ax[2])
    ax[2].set_xticks(np.arange(len(testset.classes))+0.5, testset.classes, rotation = 45)
    ax[2].set_yticks(np.arange(len(testset.classes))+0.5, testset.classes, rotation = 45)
    ax[2].set_title('CM with defense examples')
    plt.suptitle(f'Model: {key}')
    plt.show()

# %% [markdown]
# ## Accuracy

# %%
for key, defense in defense_data.items():
    print(
        str(
            f"Model: {key} \n" +
            f"Initial Accuracy {accuracy_score(defense['real_labels'], defense['model_labels'])} \n" +
            f"Adversarial Accuracy {accuracy_score(defense['real_labels'], defense['adversarial_labels'])} \n" +
            f"Defense Accuracy {accuracy_score(defense['real_labels'], defense['defense_labels'])} \n"
        )
    )
# Out:
# Model: Resnet
# Initial Accuracy 0.8439
# Adversarial Accuracy 0.409
# Defense Accuracy 0.6659
#
# Model: Regnet_X
# Initial Accuracy 0.8225
# Adversarial Accuracy 0.3473
# Defense Accuracy 0.6798
#
# Model: Regnet_Y
# Initial Accuracy 0.8416
# Adversarial Accuracy 0.3783
# Defense Accuracy 0.6952
